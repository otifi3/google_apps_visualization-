# %% [markdown]
# # Team 48

# %%
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import plotly.io as pio
import plotly.express as px
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df2=pd.read_csv('googleplaystore_user_reviews.csv')

# %%
df2
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
fig = px.histogram(data_frame=df.sort_values(by='Rating'), x='Category', y="Reviews",histfunc="sum",
                   color_discrete_sequence=['cyan'])

fig.update_layout(font=dict(family='Lato', size=18, color='black'), 
                  title=dict(text='Relation between category and number of reviews',
                           font=dict(size=30), x=.5), 
                  paper_bgcolor= 'white', plot_bgcolor='white',
                 xaxis = dict(title='Categorys', showgrid=False),
                 yaxis=dict(showgrid=False),bargap=0.2)
# Out:
# <div>
#
#
#             <div id="0f4da8cf-73b0-4268-bf14-675d09128ba6" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f4da8cf-73b0-4268-bf14-675d09128ba6")) {
#                     Plotly.newPlot(
#                         '0f4da8cf-73b0-4268-bf14-675d09128ba6',
# ...

# %%
#df['Installs'] = df['Installs'].replace(",","0",inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df2.dropna(axis=0, subset=["Translated_Review"], inplace=True)

# %%
df2
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
col = "Sentiment"
grouped = df2[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=400, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="a8827a88-84f4-42b5-9569-8a6fc8900b1d" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8827a88-84f4-42b5-9569-8a6fc8900b1d")) {
#                     Plotly.newPlot(
#                         'a8827a88-84f4-42b5-9569-8a6fc8900b1d',
#                         [{"labels": ["Positive", "Negative", "Neutral"], "marker": {"colors": ["#6ad49b", "#a678de"]}, "pull": [0.05, 0], "type": "pie", "values": [23998, 8271, 5158]}],
# ...

# %%
df[["months","years"]]= df["Last Updated"].str.split(",",expand=True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = px.data.gapminder().query("year==2018")
fig = px.treemap(df, path=[px.Constant("Content"), 'Content Rating', 'Category'], values='Installs',
                  color='Reviews', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['Reviews'], weights=df['Installs']))
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-220-fc4643bc6288> in <module>
#       1 df = px.data.gapminder().query("year==2018")
# ----> 2 fig = px.treemap(df, path=[px.Constant("Content"), 'Content Rating', 'Category'], values='Installs',
#       3                   color='Reviews', hover_data=['iso_alpha'],
#       4                   color_continuous_scale='RdBu',
#       5                   color_continuous_midpoint=np.average(df['Reviews'], weights=df['Installs']))
#
# AttributeError: module 'plotly.express' has no attribute 'treemap'

# %%
$ pip install plotly==5.5.0
# Out:
#   File "<ipython-input-222-c80245d6b5ed>", line 1
#     $ pip install plotly==5.5.0
#     ^
# SyntaxError: invalid syntax

# %%
pip install plotly==5.5.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'D:\Programms' is not recognized as an internal or external command,
# operable program or batch file.
